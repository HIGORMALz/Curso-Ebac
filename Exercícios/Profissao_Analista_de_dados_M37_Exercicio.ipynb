# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Amazon Web Services;</li>
#   <li>AWS IAM;</li>
#   <li>AWS S3;</li>
#   <li>AWS Athena.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Amazon Web Services

# %% [markdown]
#  1. Crie uma conta na [AWS](https://portal.aws.amazon.com/);
#  1. Acesse a sua conta e selecione a região mais próxima da sua residência.

# %% [markdown]
# ## 2\. AWS S3

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.to_csv('iris.csv', index=False, header=False)

# %% [markdown]
# * **Bucket criado com o arquivo inserido**

# %% [markdown]
# ![bucket_criado.png](data:image/png;base64,...)

# %% [markdown]
# ## 3\. AWS Athena

# %% [markdown]
# Replique as atividades do item 4.3 em sua conta.

# %% [markdown]
# * **Criação da tabela com (SQL) utilizando o bucket 'modulo37-higor-ebac'**

# %% [markdown]
# ![criacao_tabela_athena.png](data:image/png;base64,...)

# %% [markdown]
# * **Executando consultas SQL**

# %% [markdown]
# > ```sql
# SELECT * FROM iris LIMIT 10;
# ```
#
# ![resultado_query1.csv.png](data:image/png;base64,...)

# %% [markdown]
# > ```sql
# SELECT
#     specie,
#     round(avg(sepal_length), 4) as avg_sepal_length,
#     round(avg(sepal_width),  4) as avg_sepal_width,
#     round(avg(petal_length), 4) as avg_petal_length,
#     round(avg(petal_width),  4) as avg_petal_width
# FROM iris
# GROUP BY specie;
# ```
#
# ![resultado_query2.csv.png](data:image/png;base64,...)
